# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.sample(10)
# Out:
#               job_title_short  \
# 273502         Data Scientist
# 686358           Data Analyst
# 161485          Data Engineer
# 384657         Data Scientist
# 376460         Data Scientist
# 415758      Software Engineer
# 232563  Senior Data Scientist
# 541393      Software Engineer
# 390259         Data Scientist
# 555648         Data Scientist
#
#                                                 job_title  \
# 273502             Real-Time Bidding Data Science Manager
# 686358                           Consumer Insight Analyst
# 161485                           Data Engineer Consultant
# 384657                    Python Developer/Data Scientist
# 376460                           BI/Data Scientist-Senior
# 415758  Software Engineer (Web or Mobile Application) ...
# 232563                    Senior Web Analytics Consultant
# 541393                         Engenheira de Dados Sênior
# 390259                                    Data Processing
# 555648           AI Model Validation Quantitative Analyst
#
#                                  job_location                    job_via  \
# 273502                        Los Angeles, CA            via Trabajo.org
# 686358                      Bangkok, Thailand                  via BeBee
# 161485                            Netherlands  via Vacatures Trabajo.org
# 384657                          United States                  via BeBee
# 376460                           Virginia, MN                  via BeBee
# 415758                     Songkhla, Thailand                  via JobTH
# 232563                      Helsinki, Finland            via Trabajo.org
# 541393  São Paulo, State of São Paulo, Brazil               via LinkedIn
# 390259                    Copenhagen, Denmark            via Trabajo.org
# 555648                    Zürich, Switzerland                   via XING
#
#                job_schedule_type  job_work_from_home  \
# 273502                 Full-time               False
# 686358                 Full-time               False
# 161485                 Full-time               False
# 384657  Contractor and Temp work               False
# 376460                 Full-time               False
# 415758                 Full-time               False
# 232563                 Full-time               False
# 541393                 Full-time               False
# 390259                 Full-time               False
# 555648                 Full-time               False
#
#                   search_location     job_posted_date  job_no_degree_mention  \
# 273502  California, United States 2023-06-19 07:05:33                  False
# 686358                   Thailand 2023-10-27 10:22:56                  False
# 161485                Netherlands 2023-12-08 15:27:57                   True
# 384657                      Sudan 2023-10-09 18:41:18                   True
# 376460    Illinois, United States 2023-10-09 18:27:37                  False
# 415758                   Thailand 2023-10-19 17:02:49                  False
# 232563                    Finland 2023-07-29 07:27:44                   True
# 541393                     Brazil 2023-11-07 19:10:35                   True
# 390259                    Denmark 2023-08-01 18:26:51                   True
# 555648                Switzerland 2023-02-16 19:37:49                  False
#
#         job_health_insurance    job_country salary_rate  salary_year_avg  \
# 273502                 False  United States        None              NaN
# 686358                 False       Thailand        None              NaN
# 161485                 False    Netherlands        None              NaN
# 384657                 False          Sudan        None              NaN
# 376460                 False  United States        None              NaN
# 415758                 False       Thailand        None              NaN
# 232563                 False        Finland        None              NaN
# 541393                 False         Brazil        None              NaN
# 390259                 False        Denmark        None              NaN
# 555648                 False    Switzerland        None              NaN
#
#         salary_hour_avg                                company_name  \
# 273502              NaN                                Burtch Works
# 686358              NaN                                   Wisesight
# 161485              NaN                                       Yacht
# 384657              NaN                    ASB Solutions Group Inc.
# 376460              NaN                                      Jacobs
# 415758              NaN  บริษัท ศรีตรัง แอโกรอินดัสทรี จำกัด(มหาชน)
# 232563              NaN                               Columbia Road
# 541393              NaN                                   Getninjas
# 390259              NaN                                   Medtronic
# 555648              NaN                                         UBS
#
#                                                job_skills  \
# 273502              ['python', 'aws', 'spark', 'tableau']
# 686358     ['powerpoint', 'excel', 'power bi', 'tableau']
# 161485                                               None
# 384657         ['python', 'java', 'docker', 'kubernetes']
# 376460  ['python', 'r', 'sql', 'oracle', 'numpy', 'pan...
# 415758                                           ['flow']
# 232563       ['html', 'javascript', 'css', 'python', 'c']
# 541393                              ['python', 'pyspark']
# 390259                                             ['go']
# 555648                             ['r', 'python', 'sql']
#
#                                           job_type_skills
# 273502  {'analyst_tools': ['tableau'], 'cloud': ['aws'...
# 686358  {'analyst_tools': ['powerpoint', 'excel', 'pow...
# 161485                                               None
# 384657  {'other': ['docker', 'kubernetes'], 'programmi...
# 376460  {'analyst_tools': ['tableau'], 'cloud': ['orac...
# 415758                                {'other': ['flow']}
# 232563  {'programming': ['html', 'javascript', 'css', ...
# 541393  {'libraries': ['pyspark'], 'programming': ['py...
# 390259                            {'programming': ['go']}
# 555648            {'programming': ['r', 'python', 'sql']}

# %%
df.sample(10, random_state = 18)
# Out:
#               job_title_short  \
# 17930          Data Scientist
# 563027       Business Analyst
# 474391           Data Analyst
# 480129  Senior Data Scientist
# 168872         Data Scientist
# 158613       Business Analyst
# 589323           Data Analyst
# 711473         Data Scientist
# 410101           Data Analyst
# 515103          Data Engineer
#
#                                                 job_title  \
# 17930                                      Data Scientist
# 563027                  Senior Economic Reporting Analyst
# 474391                                       Data Analyst
# 480129                              Gegevenswetenschapper
# 168872                                     Data Scientist
# 158613                                   Business Analyst
# 589323            Senior / Data Analyst (Data Management)
# 711473  Lead Clinical Data Scientist - Med Tech - Irvi...
# 410101                          Supply Chain Data Analyst
# 515103                              Digital Data Engineer
#
#                                           job_location  \
# 17930                                       Luxembourg
# 563027                            Bratislava, Slovakia
# 474391                                   Fort Mill, SC
# 480129                          Rotterdam, Netherlands
# 168872                                  Manchester, UK
# 158613  Florence, Metropolitan City of Florence, Italy
# 589323                           To Kwa Wan, Hong Kong
# 711473                                     Raleigh, NC
# 410101                                     Atlanta, GA
# 515103                                  Warsaw, Poland
#
#                                                  job_via job_schedule_type  \
# 17930                                         via Indeed         Full-time
# 563027                                via BeBee Slovakia         Full-time
# 474391                                      via LinkedIn        Contractor
# 480129                                         via BeBee         Full-time
# 168872                                     via WJHL Jobs         Full-time
# 158613                            via Lavoro Trabajo.org         Full-time
# 589323                            via CAIA Career Center         Full-time
# 711473  via USNLX Virtual Jobs - National Labor Exchange         Full-time
# 410101                                   via Trabajo.org         Full-time
# 515103                                      via LinkedIn         Full-time
#
#         job_work_from_home search_location     job_posted_date  \
# 17930                False      Luxembourg 2023-10-16 13:54:54
# 563027               False        Slovakia 2023-01-05 04:56:52
# 474391               False         Georgia 2023-02-02 15:01:07
# 480129               False     Netherlands 2023-12-05 14:23:39
# 168872               False  United Kingdom 2023-07-05 15:17:40
# 158613               False           Italy 2023-05-04 08:18:56
# 589323               False       Hong Kong 2023-06-30 09:30:31
# 711473               False         Georgia 2023-07-11 02:53:22
# 410101               False         Georgia 2023-05-05 17:19:45
# 515103               False          Poland 2023-09-08 12:19:16
#
#         job_no_degree_mention  job_health_insurance     job_country  \
# 17930                   False                 False      Luxembourg
# 563027                  False                 False        Slovakia
# 474391                  False                  True   United States
# 480129                  False                 False     Netherlands
# 168872                  False                 False  United Kingdom
# 158613                  False                 False           Italy
# 589323                   True                 False       Hong Kong
# 711473                  False                  True   United States
# 410101                  False                 False   United States
# 515103                   True                 False          Poland
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 17930         None              NaN              NaN
# 563027        None              NaN              NaN
# 474391        None              NaN              NaN
# 480129        None              NaN              NaN
# 168872        None              NaN              NaN
# 158613        None              NaN              NaN
# 589323        None              NaN              NaN
# 711473        None              NaN              NaN
# 410101        None              NaN              NaN
# 515103        None              NaN              NaN
#
#                              company_name  \
# 17930                       ArcelorMittal
# 563027                           Swiss Re
# 474391       Strategic Staffing Solutions
# 480129                          Veneficus
# 168872                   RP International
# 158613  Professional Values Italia S.r.l.
# 589323  Bank Of China (Hong Kong) Limited
# 711473            J&J Family of Companies
# 410101   Children's Healthcare of Atlanta
# 515103  SPEEDmanagement Polska Sp. z o.o.
#
#                                                job_skills  \
# 17930   ['sql', 'python', 'bash', 'mysql', 'oracle', '...
# 563027                            ['excel', 'powerpoint']
# 474391  ['sql', 'sas', 'sas', 'word', 'tableau', 'excel']
# 480129         ['python', 'sql', 'flow', 'git', 'docker']
# 168872                        ['python', 'sql', 'docker']
# 158613                                               None
# 589323                                  ['sql', 'python']
# 711473              ['css', 'python', 'r', 'scala', 'go']
# 410101                                         ['sheets']
# 515103  ['azure', 'databricks', 'sap', 'jira', 'conflu...
#
#                                           job_type_skills
# 17930   {'analyst_tools': ['tableau'], 'cloud': ['orac...
# 563027         {'analyst_tools': ['excel', 'powerpoint']}
# 474391  {'analyst_tools': ['sas', 'word', 'tableau', '...
# 480129  {'other': ['flow', 'git', 'docker'], 'programm...
# 168872  {'other': ['docker'], 'programming': ['python'...
# 158613                                               None
# 589323                 {'programming': ['sql', 'python']}
# 711473  {'programming': ['css', 'python', 'r', 'scala'...
# 410101                      {'analyst_tools': ['sheets']}
# 515103  {'analyst_tools': ['sap'], 'async': ['jira', '...

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df_original = dataset['train'].to_pandas()

# %%
df_altered = df_original.copy()

# %%
median_salary = df_altered['salary_year_avg'].median()
df_altered['salary_year_avg'] = df_altered['salary_year_avg'].fillna(median_salary)
df_altered.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
df_original.loc[:5,'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64
