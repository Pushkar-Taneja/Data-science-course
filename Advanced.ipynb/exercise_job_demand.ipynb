# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df_uk = df[df['job_country']== 'United Kingdom'].copy()

# %%
df_uk['job_posted_month'] = df_uk['job_posted_date'].dt.strftime('%B')
df_uk
# Out:
#               job_title_short  \
# 15              Data Engineer
# 45        Senior Data Analyst
# 74               Data Analyst
# 97               Data Analyst
# 152            Data Scientist
# ...                       ...
# 785485           Data Analyst
# 785513         Data Scientist
# 785522          Data Engineer
# 785642          Data Engineer
# 785676  Senior Data Scientist
#
#                                                 job_title    job_location  \
# 15                                          Data Engineer    Aberdeen, UK
# 45                                    Senior Data Analyst       Leeds, UK
# 74                       Data Entry/Economic Data Analyst   Worcester, UK
# 97      Systems & Data Analyst - Exploitation, Missing...  United Kingdom
# 152                                Data Science Team Lead        Anywhere
# ...                                                   ...             ...
# 785485                               Data Quality Analyst        Anywhere
# 785513                                     Data Scientist     Glasgow, UK
# 785522                                 Lead Data Engineer      London, UK
# 785642  Submission for the position: Data Engineer Sen...     England, UK
# 785676                              Senior Data Scientist      London, UK
#
#                             job_via         job_schedule_type  \
# 15                     via LinkedIn                 Temp work
# 45            via My Stateline Jobs                 Full-time
# 74                        via BeBee                 Full-time
# 97                    via Totaljobs  Full-time and Contractor
# 152                via OnlyDataJobs                 Full-time
# ...                             ...                       ...
# 785485                 via LinkedIn                 Full-time
# 785513         via Jobs Trabajo.org                 Full-time
# 785522         via Jobs Trabajo.org                 Full-time
# 785642  via BAE Systems - Talentify                 Full-time
# 785676         via Jobs Trabajo.org                 Full-time
#
#         job_work_from_home search_location     job_posted_date  \
# 15                   False  United Kingdom 2023-10-19 13:37:16
# 45                   False  United Kingdom 2023-05-30 13:14:08
# 74                   False  United Kingdom 2023-11-01 13:11:18
# 97                   False  United Kingdom 2023-12-04 13:14:01
# 152                   True  United Kingdom 2023-12-23 13:12:16
# ...                    ...             ...                 ...
# 785485                True  United Kingdom 2023-10-04 06:09:44
# 785513               False  United Kingdom 2023-01-22 06:21:21
# 785522               False  United Kingdom 2023-01-19 06:16:45
# 785642               False  United Kingdom 2023-01-02 06:31:23
# 785676               False  United Kingdom 2023-01-22 06:21:23
#
#         job_no_degree_mention  job_health_insurance     job_country  \
# 15                      False                 False  United Kingdom
# 45                       True                 False  United Kingdom
# 74                      False                 False  United Kingdom
# 97                       True                 False  United Kingdom
# 152                     False                 False  United Kingdom
# ...                       ...                   ...             ...
# 785485                  False                 False  United Kingdom
# 785513                  False                 False  United Kingdom
# 785522                   True                 False  United Kingdom
# 785642                   True                 False  United Kingdom
# 785676                  False                 False  United Kingdom
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 15            None              NaN              NaN
# 45            None              NaN              NaN
# 74            None              NaN              NaN
# 97            None              NaN              NaN
# 152           None              NaN              NaN
# ...            ...              ...              ...
# 785485        None              NaN              NaN
# 785513        None              NaN              NaN
# 785522        None              NaN              NaN
# 785642        None              NaN              NaN
# 785676        None              NaN              NaN
#
#                                     company_name  \
# 15                                   Orion Group
# 45                            Corecom Consulting
# 74                            ttgTalentSolutions
# 97         Solihull Metropolitan Borough Council
# 152                              StepStone Group
# ...                                          ...
# 785485                                   Viatris
# 785513                           ASA Recruitment
# 785522                       bionic-services-ltd
# 785642                          BAE Systems - UK
# 785676  Department for International Development
#
#                                                job_skills  \
# 15                          ['python', 'sql', 'power bi']
# 45                                      ['sql', 'python']
# 74          ['sql', 'r', 'python', 'tableau', 'power bi']
# 97                                                   None
# 152                                   ['react', 'docker']
# ...                                                   ...
# 785485       ['sql', 'sql server', 'excel', 'powerpoint']
# 785513                                  ['r', 'power bi']
# 785522  ['sql', 'python', 'sql server', 'aws', 'snowfl...
# 785642  ['python', 'vue', 'ssis', 'ssrs', 'qlik', 'con...
# 785676                                    ['r', 'python']
#
#                                           job_type_skills job_posted_month
# 15      {'analyst_tools': ['power bi'], 'programming':...          October
# 45                     {'programming': ['sql', 'python']}              May
# 74      {'analyst_tools': ['tableau', 'power bi'], 'pr...         November
# 97                                                   None         December
# 152         {'libraries': ['react'], 'other': ['docker']}         December
# ...                                                   ...              ...
# 785485  {'analyst_tools': ['excel', 'powerpoint'], 'da...          October
# 785513  {'analyst_tools': ['power bi'], 'programming':...          January
# 785522  {'analyst_tools': ['ssis'], 'cloud': ['aws', '...          January
# 785642  {'analyst_tools': ['ssis', 'ssrs', 'qlik'], 'a...          January
# 785676                   {'programming': ['r', 'python']}          January
#
# [40375 rows x 18 columns]

# %%
df_uk_pivot.reset_index(inplace=True)
df_uk_pivot['month_no']=pd.to_datetime(df_uk_pivot['job_posted_month'], format='%B').dt.month
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df_uk_pivot.reset_index(inplace=True)
#       2 df_uk_pivot['month_no']=pd.to_datetime(df_uk_pivot['job_posted_month'], format='%B').dt.month
#
# NameError: name 'df_uk_pivot' is not defined

# %%
df_uk_pivot.sort_values('month_no', inplace=True)
df_uk_pivot.set_index('job_posted_month', inplace=True)
df_uk_pivot.drop(columns='month_no', inplace=True)

# %%
df_uk_pivot
# Out:
# job_title         'Hands on' PBI & SQL Analytics Manager  \
# job_posted_month
# January                                              NaN
# February                                             NaN
# March                                                NaN
# April                                                NaN
# May                                                  NaN
# June                                                 NaN
# July                                                 NaN
# August                                               NaN
# September                                            NaN
# October                                              1.0
# November                                             NaN
# December                                             NaN
#
# job_title         (-/Senior/Principal) NLP Scientist (Remote)  \
# job_posted_month
# January                                                   NaN
# February                                                  NaN
# March                                                     NaN
# April                                                     NaN
# May                                                       NaN
# June                                                      NaN
# July                                                      NaN
# August                                                    NaN
# September                                                 NaN
# October                                                   NaN
# November                                                  1.0
# December                                                  NaN
#
# job_title         (07/10/2023) Data Engineer  \
# job_posted_month
# January                                  NaN
# February                                 NaN
# March                                    NaN
# April                                    NaN
# May                                      NaN
# June                                     NaN
# July                                     NaN
# August                                   NaN
# September                                NaN
# October                                  1.0
# November                                 NaN
# December                                 NaN
#
# job_title         (10/11/2023) Lead Data Scientist  \
# job_posted_month
# January                                        NaN
# February                                       NaN
# March                                          NaN
# April                                          NaN
# May                                            NaN
# June                                           NaN
# July                                           NaN
# August                                         NaN
# September                                      NaN
# October                                        NaN
# November                                       1.0
# December                                       NaN
#
# job_title         (15h Left) Analyst/Associate, Data Science  \
# job_posted_month
# January                                                  NaN
# February                                                 NaN
# March                                                    NaN
# April                                                    NaN
# May                                                      NaN
# June                                                     NaN
# July                                                     NaN
# August                                                   NaN
# September                                                NaN
# October                                                  1.0
# November                                                 NaN
# December                                                 NaN
#
# job_title         (15h Left) Data Engineer  (15h Left) Senior Data  \
# job_posted_month
# January                                NaN                     NaN
# February                               NaN                     NaN
# March                                  NaN                     NaN
# April                                  NaN                     NaN
# May                                    NaN                     NaN
# June                                   NaN                     NaN
# July                                   NaN                     NaN
# August                                 NaN                     NaN
# September                              NaN                     NaN
# October                                1.0                     NaN
# November                               1.0                     1.0
# December                               NaN                     NaN
#
# job_title         (15h Left) Senior Python/Data Engineer  \
# job_posted_month
# January                                              NaN
# February                                             NaN
# March                                                NaN
# April                                                NaN
# May                                                  NaN
# June                                                 NaN
# July                                                 NaN
# August                                               NaN
# September                                            NaN
# October                                              NaN
# November                                             1.0
# December                                             NaN
#
# job_title         (16/09/2023) Data Analyst  \
# job_posted_month
# January                                 NaN
# February                                NaN
# March                                   NaN
# April                                   NaN
# May                                     NaN
# June                                    NaN
# July                                    NaN
# August                                  NaN
# September                               1.0
# October                                 NaN
# November                                NaN
# December                                NaN
#
# job_title         (22/10/2023) Senior Data Engineer SQL ETL Cloud  ...  \
# job_posted_month                                                   ...
# January                                                       NaN  ...
# February                                                      NaN  ...
# March                                                         NaN  ...
# April                                                         NaN  ...
# May                                                           NaN  ...
# June                                                          NaN  ...
# July                                                          NaN  ...
# August                                                        NaN  ...
# September                                                     NaN  ...
# October                                                       1.0  ...
# November                                                      NaN  ...
# December                                                      NaN  ...
#
# job_title         🌳🌳Data Analyst/Information Analyst (NHS)🌳  \
# job_posted_month
# January                                                 NaN
# February                                                NaN
# March                                                   NaN
# April                                                   NaN
# May                                                     NaN
# June                                                    NaN
# July                                                    NaN
# August                                                  NaN
# September                                               NaN
# October                                                 1.0
# November                                                NaN
# December                                                NaN
#
# job_title         🌳🌳Data Engineer 🌳  🌳🌳🌳  Data Analyst - FTC - Remote  🌳🌳🌳  \
# job_posted_month
# January                         NaN                                    NaN
# February                        NaN                                    NaN
# March                           NaN                                    NaN
# April                           NaN                                    NaN
# May                             NaN                                    NaN
# June                            NaN                                    NaN
# July                            NaN                                    NaN
# August                          NaN                                    NaN
# September                       NaN                                    NaN
# October                         1.0                                    NaN
# November                        NaN                                    1.0
# December                        NaN                                    NaN
#
# job_title         🌳🌳🌳  Data Analyst - Remote  🌳🌳🌳  \
# job_posted_month
# January                                       NaN
# February                                      NaN
# March                                         NaN
# April                                         NaN
# May                                           NaN
# June                                          NaN
# July                                          NaN
# August                                        NaN
# September                                     NaN
# October                                       NaN
# November                                      1.0
# December                                      1.0
#
# job_title         🌳🌳🌳 Data Engineer - Informatica Powercenter 🌳🌳🌳  \
# job_posted_month
# January                                                       NaN
# February                                                      NaN
# March                                                         1.0
# April                                                         NaN
# May                                                           NaN
# June                                                          NaN
# July                                                          NaN
# August                                                        NaN
# September                                                     NaN
# October                                                       NaN
# November                                                      NaN
# December                                                      NaN
#
# job_title         🌳🌳🌳Junior Data Engineer - SAS/Python🌳🌳🌳  \
# job_posted_month
# January                                               NaN
# February                                              1.0
# March                                                 NaN
# April                                                 NaN
# May                                                   NaN
# June                                                  NaN
# July                                                  NaN
# August                                                NaN
# September                                             NaN
# October                                               NaN
# November                                              NaN
# December                                              NaN
#
# job_title         🌳🌳🌳Senior Data Engineer  🌳🌳🌳  \
# job_posted_month
# January                                    NaN
# February                                   NaN
# March                                      NaN
# April                                      NaN
# May                                        NaN
# June                                       NaN
# July                                       NaN
# August                                     1.0
# September                                  NaN
# October                                    NaN
# November                                   NaN
# December                                   NaN
#
# job_title         🌳🌳🌳Strategic/Commercial Data Analyst - Outside IR35 - Remote  ...  \
# job_posted_month
# January                                                         NaN
# February                                                        1.0
# March                                                           NaN
# April                                                           NaN
# May                                                             NaN
# June                                                            NaN
# July                                                            NaN
# August                                                          NaN
# September                                                       NaN
# October                                                         NaN
# November                                                        NaN
# December                                                        NaN
#
# job_title         🌳🌳🌳X 8 Data Software Engineers – Strong ETL, AWS & Python...  \
# job_posted_month
# January                                                         NaN
# February                                                        NaN
# March                                                           NaN
# April                                                           NaN
# May                                                             NaN
# June                                                            NaN
# July                                                            NaN
# August                                                          NaN
# September                                                       NaN
# October                                                         NaN
# November                                                        1.0
# December                                                        NaN
#
# job_title         🏴☠ 🦜 Graduate Data Scientist  🏴☠ 🦜😅
# job_posted_month
# January                                           NaN
# February                                          NaN
# March                                             NaN
# April                                             NaN
# May                                               NaN
# June                                              NaN
# July                                              NaN
# August                                            NaN
# September                                         NaN
# October                                           NaN
# November                                          1.0
# December                                          NaN
#
# [12 rows x 11827 columns]

# %%
top_3 = df_uk['job_title_short'].value_counts().head(3)
top_3=top_3.index.to_list()

# %%
df_uk_pivot[top_3].plot(kind = 'line')
# Out:
# <Axes: xlabel='job_posted_month'>
